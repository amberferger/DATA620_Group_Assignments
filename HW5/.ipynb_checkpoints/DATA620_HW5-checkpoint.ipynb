# %% [markdown]
# ### CUNY Data 620 - Web Analytics, Summer 2020
# **Group Homework Assignment 5**
# **Prof:** Alain Ledon
# **Members:** Misha Kollontai, Amber Ferger, Zach Alexander, Subhalaxmi Rout

# %% [markdown]
# ### Instructions
#
# 1. Choose a corpus of interest.
# 2. How many total unique words are in the corpus? (Please feel free to define unique words in any interesting, defensible way).
# 3. Taking the most common words, how many unique words represent half of the total words in the corpus?
# 4. Identify the 200 highest frequency words in this corpus.
# 5. Create a graph that shows the relative frequency of these 200 words.
# 6. Does the observed relative frequency of these words follow Zipf’s law? Explain.
# 7. In what ways do you think the frequency of the words in this corpus differ from “all words in all corpora.”

# %% [markdown]
# ### Import Packages

# %%
import nltk
# nltk.download()
from nltk.book import text6 # Monty Python and the Holy Grail
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt

# %% [markdown]
# ### (1) Choose a corpus of interest.
# We have chosen to use the *Monty Python and the Holy Grail* corpus that comes with the nltk library. We will define the following:
#
# * **tokens**: words, numbers, and punctuations
# * **words**: alphabetic tokens
# * **lexical diversity**: a measure of the richness of the text -- this will tell us on average how many times a word or token is used in the text

# %% [markdown]
# ### (2) How many total unique words are in the corpus?
# We define **unique words** as the distinct, uncommon, non-case sensitive, alphabetic tokens in the text. Our process will be to:
# 1. Convert all tokens in the text to lowercase. This will eliminate variations in case-sensitivity.
# 2. Remove non-alphabetic tokens.
# 3. Remove all stopwords from the text. This will eliminate commonly used words (ex: the, or, and).
# 4. Stem our words so that we are removing variations based on plurality or tense (ex: was, be, is).
# 5. Calculate the total number of unique words from the set of words in the text.

# %%
# create a function to remove stopwords
def remove_stopwords(text):
    stopWords = nltk.corpus.stopwords.words('english')
    finalText = [word for word in text if word not in stopWords]
    return(finalText)

# convert everything to lowercase, remove stopwords
finalTokens = [token.lower() for token in text6]
words = [term for term in finalTokens if term.isalpha()]
noStopWords = remove_stopwords(words)

# stemmed words
porter = PorterStemmer()
stemmedWords = []
for word in noStopWords:
    stemmedWords.append(porter.stem(word))

# unique words
uniqueWords = set(stemmedWords)

# define counts
numWords = len(words)
numNoStop = len(noStopWords)
numUniqueWords = len(uniqueWords)
lexDivWords = numWords/ numUniqueWords

print('Total tokens: ', len(text6))
print('Total words - all alphabetic: ', numWords)
print('Total words - no stopwords: ', numNoStop)
print('Unique words - stemmed, no stopwords: ', numUniqueWords)
print('Lexical diversity (words): ', lexDivWords)
# Out:
# Total tokens:  16967
# Total words - all alphabetic:  11450
# Total words - no stopwords:  6692
# Unique words - stemmed, no stopwords:  1481
# Lexical diversity (words):  7.731262660364618

# %% [markdown]
# This shows that sequentially removing punctuation, capitalization, and stopwords, and stemming the words results in a unique word list that is only ~9% of the total corpus!

# %% [markdown]
# ### (3) Taking the most common words, how many unique words represent half of the total words in the corpus?
# We can use the **FreqDist** function from the nltk library to calculate the frequencies of the words in our unique word list. We will sort the words in descending order, add up the cumulative frequency, and identify how many unique words represent half the total words in the corpus.
#
# *Note that we define the total words in the corpus as alphabetic tokens only.*

# %%
fdist = FreqDist(stemmedWords)
sortedFreq = {k: v for k, v in sorted(fdist.items(), key=lambda item: item[1], reverse=True)}

cumsum = 0
record = 0
for e, value in enumerate(sortedFreq.values()):
    if cumsum <= numWords/2:
        cumsum += value
        record = e

print('Total words in the corpus - alphabetic: ', numWords)
print('Half of the words in the corpus: ', numWords/2)
print('Number of unique words in the corpus: ', numUniqueWords)
print('Number of unique words representing half the total words in the corpus:', record)
print('Percent of unique words: ', record/numUniqueWords)
#plt.figure(figsize=(20, 5))
#fdist.plot(record, cumulative=True)
# Out:
# Total words in the corpus - alphabetic:  11450
# Half of the words in the corpus:  5725.0
# Number of unique words in the corpus:  1481
# Number of unique words representing half the total words in the corpus: 606
# Percent of unique words:  0.4091829844699527

# %% [markdown]
# This tells us that about 40% of the unique words in the corpus represent half of the total words in the text!

# %% [markdown]
# ### (4) Identify the 200 highest frequency words in this corpus.
# Here, we'll take a look at all alphabetic words - not stemmed and with no stopwords removed.

# %%
fdistAll = FreqDist(words)
sortedFreqAll = {k: v for k, v in sorted(fdistAll.items(), key=lambda item: item[1], reverse=True)}
highestFreqWords = list(sortedFreqAll.items())[:200]

# top 10 words
print('Top 10 words in the corpus:','\n', highestFreqWords[0:10])
# Out:
# Top 10 words in the corpus:
#  [('the', 334), ('you', 265), ('arthur', 261), ('i', 260), ('a', 238), ('and', 185), ('of', 178), ('to', 151), ('s', 145), ('it', 142)]

# %% [markdown]
# Not surprisingly, many of the top words are very common - these were filtered out of the unique word list with the elimination of stopwords. In fact, we can identify the percentage of words in the top 200 list that are stopwords:

# %%
swTop200 = []
for word,value in highestFreqWords:
    if word in stopWords:
        swTop200.append([word,value])

print('Total number of stopwords in top 200 list: ', len(swTop200))
print('Total percent of words in top 200 that are stopwords: ', len(swTop200)/len(highestFreqWords))
# Out:
# Total number of stopwords in top 200 list:  78
# Total percent of words in top 200 that are stopwords:  0.39

# %% [markdown]
# ### (5) Create a graph that shows the relative frequency of these 200 words.

# %%
plt.figure(figsize=(35, 5))
fdistAll.plot(200)

# %% [markdown]
# ### (6) Does the observed relative frequency of these words follow Zipf’s law? Explain.

# %% [markdown]
# ### (7) In what ways do you think the frequency of the words in this corpus differ from “all words in all corpora.”
